# %% [markdown]
# import the pandas libraries

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/List of Countries by Sugarcane Production.csv')

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %% [markdown]
# In pandas, df.head() and df.tail() are methods used to view the first and last few rows of a DataFrame, respectively. They are useful for quickly inspecting the data without displaying the entire DataFrame.

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %% [markdown]
# default last five rows find

# %%
df.tail()
# Out:
#      Unnamed: 0    Country Continent Production (Tons)  \
# 98           98    Lebanon      Asia                97
# 99           99   Djibouti    Africa                53
# 100         100  Singapore      Asia                50
# 101         101      Samoa   Oceania                12
# 102         102      Syria      Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2

# %% [markdown]
# df.info() is a method in pandas that provides a concise summary of a DataFrame. This summary includes information about the index, data types, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %% [markdown]
# Certainly! To use df.shape to get the dimensions of a DataFrame in pandas, you simply access the shape attribute of the DataFrame. Below is a step-by-step example demonstrating how to do this.

# %%
df.shape
# Out:
# (103, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Continent', 'Production (Tons)',
#        'Production per Person (Kg)', 'Acreage (Hectare)',
#        'Yield (Kg / Hectare)'],
#       dtype='object')

# %% [markdown]
# In pandas, df.dtypes is an attribute that provides the data types of each column in a DataFrame. It returns a Series with the column names as the index and the corresponding data types as the values.

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %% [markdown]
# In pandas, df.describe() is a method that generates descriptive statistics of a DataFrame. It provides a summary of the central tendency, dispersion, and shape of the dataset’s distribution, excluding NaN values. This method is particularly useful for quickly understanding the characteristics of numerical data.

# %%
df.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %% [markdown]
# In pandas, the expression df[df['col'] == ''] is used to filter a DataFrame to return only the rows where the value in the specified column ('col' in this case) is an empty string (''). This is useful for identifying and working with rows that have missing or empty values in a specific column.

# %%
df[df['Country']=='India']
# Out:
#    Unnamed: 0 Country Continent Production (Tons) Production per Person (Kg)  \
# 1           1   India      Asia       348.448.000                     260721
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 1         4.950.000             70.393,5

# %%
df[df['Country']=='Pakistan']
# Out:
#    Unnamed: 0   Country Continent Production (Tons)  \
# 4           4  Pakistan      Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 4                     324219         1.130.820               57.879

# %%
df[df["Continent"]=="Asia"].shape
# Out:
# (25, 7)

# %% [markdown]
# In pandas, the duplicated() method is used to identify duplicate rows in a DataFrame. This method returns a boolean Series indicating whether each row is a duplicate of a previous row. You can also customize the behavior of this method to check for duplicates based on specific columns or to control which duplicates are marked.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# now Check columns by duplicate

# %%
df['Country'].duplicated().sum()
# Out:
# 0

# %%
df['Continent'].duplicated().sum()
# Out:
# 97

# %% [markdown]
# # In pandas, the isnull(),or isna() method is used to detect missing values in a DataFrame or Series.

# %%
  df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %% [markdown]
# # check column wise **null**

# %%
df[df['Acreage (Hectare)'].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df[df['Yield (Kg / Hectare)'].isna()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %% [markdown]
# # Exploring Each Column one-by-one

# %%
set(df['Continent'].values)
# Out:
# {'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'}

# %%
df.head(2)
# Out:
#    Unnamed: 0 Country      Continent Production (Tons)  \
# 0           0  Brazil  South America       768.678.382
# 1           1   India           Asia       348.448.000
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5

# %% [markdown]
# #In pandas, the .unique() method is used to find the unique values in a Series or DataFrame column. This method returns an array of the unique values

# %%
df['Continent'].unique()
# Out:
# array(['South America', 'Asia', 'North America', 'Oceania', 'Africa',
#        'Europe'], dtype=object)

# %% [markdown]
# #In pandas, the .nunique() method is used to count the number of unique values in a Series or DataFrame column.

# %%
df['Continent'].nunique()
# Out:
# 6

# %% [markdown]
# #In pandas, the .value_counts() method is used to count the unique values in a Series and return a Series containing counts of unique values in descending order.

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# # Now Data Cleaning

# %% [markdown]
# # Remove Duplicates

# %%
df.drop_duplicates()
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %% [markdown]
# # Remove Null

# %% [markdown]
# # New Section
# df=df.dropna()
# In pandas, the dropna() method is used to remove missing values (i.e., NaN values) from a DataFrame or Series. This method is useful for cleaning your data by eliminating rows or columns that contain missing values, which can be important for data analysis and modeling

# %%
df=df.dropna()

# %% [markdown]
# # In pandas, the fillna() method is used to fill missing values (i.e., NaN values) in a DataFrame or Series with a specified value or method. This is particularly useful for data cleaning and preprocessing, as it allows you to handle missing data in a way that is appropriate for your analysis.

# %%
df_nullfilled=df.fillna('')

# %%
df_nullfilled
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 97           97      Spain         Europe               394
# 98           98    Lebanon           Asia                97
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %% [markdown]
# # Cleaning and Removing Unnecessary Columns

# %% [markdown]
# # Renaming the Column Name

# %%
df.head(2)
# Out:
#    Unnamed: 0 Country      Continent Production (Tons)  \
# 0           0  Brazil  South America       768.678.382
# 1           1   India           Asia       348.448.000
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5

# %%
df.rename(columns={'Production (Tons)':'Production_Tons'},inplace=True)
df.rename(columns={'Production per Person (Kg)':'Production_per_Person_Kg'},inplace=True)
df.rename(columns={'Acreage (Hectare)':'Acreage_Hectare'},inplace=True)
df.rename(columns={'Yield (Kg / Hectare)':'Yield_Kg/Hectare'},inplace=True)
# Out:
# <ipython-input-104-cd998dfe979e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Production (Tons)':'Production_Tons'},inplace=True)
# <ipython-input-104-cd998dfe979e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Production per Person (Kg)':'Production_per_Person_Kg'},inplace=True)
# <ipython-input-104-cd998dfe979e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0 Country      Continent Production_Tons Production_per_Person_Kg  \
# 0           0  Brazil  South America     768.678.382                3.668,531
# 1           1   India           Asia     348.448.000                   260721
#
#   Acreage_Hectare Yield_Kg/Hectare
# 0      10.226.205         75.167,5
# 1       4.950.000         70.393,5

# %%
df["Production_Tons"]=df["Production_Tons"].str.replace('.','').astype(float)
# Out:
# <ipython-input-106-a382bb86311d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Production_Tons"]=df["Production_Tons"].str.replace('.','').astype(float)

# %%
df["Production_per_Person_Kg"] = df["Production_per_Person_Kg"].str.replace(".","").str.replace(",",".").astype(float)
# Out:
# <ipython-input-107-835bfa102237>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Production_per_Person_Kg"] = df["Production_per_Person_Kg"].str.replace(".","").str.replace(",",".").astype(float)

# %%
df["Acreage_Hectare"] = df["Acreage_Hectare"].str.replace(".","").astype(float)
# Out:
# <ipython-input-108-2dfd5e0e9732>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Acreage_Hectare"] = df["Acreage_Hectare"].str.replace(".","").astype(float)

# %%
df["Yield_Kg/Hectare"] = df["Yield_Kg/Hectare"].str.replace(".","").str.replace(",",".").astype(float)
# Out:
# <ipython-input-109-d5c0802f4e21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Yield_Kg/Hectare"] = df["Yield_Kg/Hectare"].str.replace(".","").str.replace(",",".").astype(float)

# %%
df.head(2)
# Out:
#    Unnamed: 0 Country      Continent  Production_Tons  \
# 0           0  Brazil  South America      768678382.0
# 1           1   India           Asia      348448000.0
#
#    Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# 0                  3668.531       10226205.0           75167.5
# 1                260721.000        4950000.0           70393.5

# %%
df.describe()
# Out:
#        Unnamed: 0  Production_Tons  Production_per_Person_Kg  Acreage_Hectare  \
# count  102.000000     1.020000e+02                102.000000     1.020000e+02
# mean    50.529412     1.850372e+07             112952.435755     2.498981e+05
# std     29.638985     8.419149e+07             176651.341929     1.137003e+06
# min      0.000000     1.000000e+00                  0.000000     0.000000e+00
# 25%     25.250000     6.251875e+04               3671.910000     1.104000e+03
# 50%     50.500000     1.440044e+06              25572.500000     1.655800e+04
# 75%     75.750000     6.426824e+06             146384.750000     8.047400e+04
# max    102.000000     7.686784e+08             951087.000000     1.022620e+07
#
#        Yield_Kg/Hectare
# count        102.000000
# mean       52628.078431
# std        30504.676683
# min           10.000000
# 25%        29072.025000
# 50%        54108.950000
# 75%        73282.700000
# max       129049.300000

# %% [markdown]
# check those Continent <> to Asia

# %%
df[df['Continent']!='Asia']
# Out:
#      Unnamed: 0              Country      Continent  Production_Tons  \
# 0             0               Brazil  South America      768678382.0
# 5             5               Mexico  North America       56446821.0
# 6             6             Colombia  South America       36951213.0
# 7             7            Australia        Oceania       34403004.0
# 8             8            Guatemala  North America       33533403.0
# ..          ...                  ...            ...              ...
# 92           92             Portugal         Europe           5429.0
# 93           93  Antigua and Barbuda  North America           5365.0
# 94           94             Dominica  North America           4855.0
# 97           97                Spain         Europe            394.0
# 101         101                Samoa        Oceania             12.0
#
#      Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# 0                    3668.531       10226205.0           75167.5
# ...

# %% [markdown]
# # In Pandas, the sort_values() function is used to sort a DataFrame or Series by one or more columns. This function allows you to specify the sorting order (ascending or descending) and can handle missing values as well.

# %%
df.sort_values('Continent', ascending=False)
# Out:
#     Unnamed: 0                   Country      Continent  Production_Tons  \
# 0            0                    Brazil  South America      768678382.0
# 12          12                 Argentina  South America       21990823.0
# 37          37                 Venezuela  South America        3331252.0
# 25          25                  Paraguay  South America        6708000.0
# 43          43                    Guyana  South America        2394553.0
# ..         ...                       ...            ...              ...
# 54          54                  Cameroon         Africa        1288732.0
# 76          76  Central African Republic         Africa         103002.0
# 53          53                   Nigeria         Africa        1337572.0
# 78          78                    Rwanda         Africa          93823.0
# 66          66                      Mali         Africa         365119.0
#
#     Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# ...

# %% [markdown]
# # Understanding KPI'S Related to 'List of Countries By Sugercan'

# %% [markdown]
# **Countries**
# # 1.Smallest/Highest production of sugarcane countrywise.

# %%
df[df['Production_Tons']==df['Production_Tons'].max()]['Country'].values
# Out:
# array(['Brazil'], dtype=object)

# %%
df[df['Production_Tons']==df['Production_Tons'].min()]['Country'].values
# Out:
# array(['Syria'], dtype=object)

# %%
df.sort_values('Production_Tons',ascending=False).head(10)['Country'].values
# Out:
# array(['Brazil', 'India', 'China', 'Thailand', 'Pakistan', 'Mexico',
#        'Colombia', 'Australia', 'Guatemala', 'United States of America'],
#       dtype=object)

# %%
df.sort_values('Production_Tons',ascending=False).head(10)[['Country','Production_Tons']].set_index('Country').plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# # Top 10 countries producing sugarcane Area Wise

# %%
df.sort_values('Acreage_Hectare',ascending=False).head(10)[['Country','Acreage_Hectare']].set_index('Country').plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production_Tons  \
# 0           0    Brazil  South America      768678382.0
# 1           1     India           Asia      348448000.0
# 2           2     China           Asia      123059739.0
# 3           3  Thailand           Asia       87468496.0
# 4           4  Pakistan           Asia       65450704.0
#
#    Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# 0                  3668.531       10226205.0           75167.5
# 1                260721.000        4950000.0           70393.5
# 2                 88287.000        1675215.0           73459.1
# 3                  1264.303        1336575.0           65442.2
# 4                324219.000        1130820.0           57879.0

# %% [markdown]
# # Relation between Acreage_Hectare & Production_Tons.

# %%
df[['Acreage_Hectare','Production_Tons']].corr()
# Out:
#                  Acreage_Hectare  Production_Tons
# Acreage_Hectare          1.00000          0.99755
# Production_Tons          0.99755          1.00000

# %%
df[["Production_per_Person_Kg" ,"Production_Tons","Acreage_Hectare", "Yield_Kg/Hectare"]].corr()
# Out:
#                           Production_per_Person_Kg  Production_Tons  \
# Production_per_Person_Kg                  1.000000         0.015000
# Production_Tons                           0.015000         1.000000
# Acreage_Hectare                           0.012557         0.997550
# Yield_Kg/Hectare                          0.017999         0.132812
#
#                           Acreage_Hectare  Yield_Kg/Hectare
# Production_per_Person_Kg         0.012557          0.017999
# Production_Tons                  0.997550          0.132812
# Acreage_Hectare                  1.000000          0.113433
# Yield_Kg/Hectare                 0.113433          1.000000

# %% [markdown]
# # all Continent Number percentage by

# %%
df['Continent'].value_counts().plot(kind='pie',autopct='%2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # country each Continents

# %%
df_continent=df.groupby('Continent').sum()

# %%
df_continent
# Out:
#                Unnamed: 0                                            Country  \
# Continent
# Africa               2061  EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia                 1253  IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                189                                      PortugalSpain
# North America        1101  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania               227                 AustraliaFijiPapua New GuineaSamoa
# South America         323  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production_Tons  Production_per_Person_Kg  Acreage_Hectare  \
# Continent
# Africa              89681472.0               2332636.293        1439089.0
# Asia               721930425.0               1857769.303       10608319.0
# Europe                  5823.0                   536.000             71.0
# North America      173995947.0               3796081.508        1581983.0
# ...

# %%
df_continent['Number_of_Contries']=df['Continent'].value_counts()

# %%
df_continent
# Out:
#                Unnamed: 0                                            Country  \
# Continent
# Africa               2061  EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia                 1253  IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                189                                      PortugalSpain
# North America        1101  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania               227                 AustraliaFijiPapua New GuineaSamoa
# South America         323  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production_Tons  Production_per_Person_Kg  Acreage_Hectare  \
# Continent
# Africa              89681472.0               2332636.293        1439089.0
# Asia               721930425.0               1857769.303       10608319.0
# Europe                  5823.0                   536.000             71.0
# North America      173995947.0               3796081.508        1581983.0
# ...

# %%
df_continent.drop("Country", axis = 1, inplace = True)

# %%
df_continent
# Out:
#                Unnamed: 0  Production_Tons  Production_per_Person_Kg  \
# Continent
# Africa               2061       89681472.0               2332636.293
# Asia                 1253      721930425.0               1857769.303
# Europe                189           5823.0                   536.000
# North America        1101      173995947.0               3796081.508
# Oceania               227       36177574.0                 28593.605
# South America         323      865588126.0               3505531.738
#
#                Acreage_Hectare  Yield_Kg/Hectare  Number_of_Contries
# Continent
# Africa               1439089.0         2142107.5                  38
# Asia                10608319.0         1171871.4                  25
# Europe                    71.0          131870.9                   2
# North America        1581983.0         1082602.4                  22
# Oceania               490909.0          162419.1                   4
# ...

# %% [markdown]
# # Visualization using matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Top 10 countries producing sugarcane with their production

# %%
df_sorted=df.sort_values('Production_Tons',ascending=False)
plt.bar(df_sorted['Country'].head(10),df_sorted['Production_Tons'].head(10),color=['green','yellow','red','Blue','black'])
plt.xticks(rotation=90)
plt.title('Top 10 countries production sugercane with their production')
plt.xlabel('country')
plt.ylabel('Acreage_Hectare')
plt.show()

# %%
corr_matrix = df[["Production_Tons","Production_per_Person_Kg", "Acreage_Hectare","Yield_Kg/Hectare"]].corr()

# %%
plt.imshow(corr_matrix, cmap = "Blues")
plt.colorbar()
plt.xticks(ticks= [0,1,2,3], labels= ["Production_tons","Production_per_person_kg", "Acreage_Hectare","Yield_kg/hectare"],rotation = 90)
plt.yticks(ticks= [0,1,2,3], labels= ["Production_tons","Production_per_person_kg", "Acreage_Hectare","Yield_kg/hectare"])
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production_Tons  \
# 0           0    Brazil  South America      768678382.0
# 1           1     India           Asia      348448000.0
# 2           2     China           Asia      123059739.0
# 3           3  Thailand           Asia       87468496.0
# 4           4  Pakistan           Asia       65450704.0
#
#    Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# 0                  3668.531       10226205.0           75167.5
# 1                260721.000        4950000.0           70393.5
# 2                 88287.000        1675215.0           73459.1
# 3                  1264.303        1336575.0           65442.2
# 4                324219.000        1130820.0           57879.0

# %% [markdown]
# # Boxplot showing all numerical columns to check in any case any country's performance is outlier.

# %%
fig, axs = plt.subplots(2,2, figsize = (10,10))

axs[0,0].boxplot(df["Production_Tons"])
axs[0,0].set_title("Production_tons")

axs[0,1].boxplot(df["Production_per_Person_Kg"])
axs[0,1].set_title("Production_per_Person_Kg")


axs[1,0].boxplot(df["Acreage_Hectare"])
axs[1,0].set_title("Acreage_Hectare")

axs[1,1].boxplot(df["Yield_Kg/Hectare"])
axs[1,1].set_title("Yield_Kg/Hectare")


plt.tight_layout()
plt.show()

# %% [markdown]
# #Smallest/Highest production of sugarcane continentwise.

# %%
df_sorted_small = df.sort_values(by = 'Acreage_Hectare', ascending = False)

# %%
df_sorted_Large = df.sort_values(by = 'Acreage_Hectare', ascending = True)

# %%
df_sorted_Large
# Out:
#      Unnamed: 0    Country      Continent  Production_Tons  \
# 102         102      Syria           Asia              1.0
# 101         101      Samoa        Oceania             12.0
# 100         100  Singapore           Asia             50.0
# 98           98    Lebanon           Asia             97.0
# 97           97      Spain         Europe            394.0
# ..          ...        ...            ...              ...
# 4             4   Pakistan           Asia       65450704.0
# 3             3   Thailand           Asia       87468496.0
# 2             2      China           Asia      123059739.0
# 1             1      India           Asia      348448000.0
# 0             0     Brazil  South America      768678382.0
#
#      Production_per_Person_Kg  Acreage_Hectare  Yield_Kg/Hectare
# 102                     0.000              0.0           83034.2
# 101                     6.000              1.0           11949.8
# ...

# %% [markdown]
# # Top 2 continents producing sugarcane.

# %%
df_sorted=df.sort_values('Production_Tons',ascending=False)
plt.bar(df_sorted['Continent'].head(2),df_sorted['Production_Tons'].head(2),color=['green','yellow'])
plt.xticks(rotation=90)
plt.title('Top 2 continent production sugercane with their production')
plt.xlabel('Continent')
plt.ylabel('Acreage_Hectare')
plt.show()

# %% [markdown]
# # How many countries are producing sugarcane in a continent? Does it effect sugarcane production?

# %%
df.head(2)
# Out:
#   Country      Continent  Production_Tons  Production_per_Person_Kg  \
# 0  Brazil  South America      768678382.0                  3668.531
# 1   India           Asia      348448000.0                260721.000
#
#    Acreage_Hectare  Yield_Kg/Hectare
# 0       10226205.0           75167.5
# 1        4950000.0           70393.5

# %%
df = df.drop("Unnamed: 0",axis = 1)

# %%
country_count=df.groupby('Continent').count()

# %%
country_count
# Out:
#                Country  Production_Tons  Production_per_Person_Kg  \
# Continent
# Africa              38               38                        38
# Asia                25               25                        25
# Europe               2                2                         2
# North America       22               22                        22
# Oceania              4                4                         4
# South America       11               11                        11
#
#                Acreage_Hectare  Yield_Kg/Hectare
# Continent
# Africa                      38                38
# Asia                        25                25
# Europe                       2                 2
# North America               22                22
# Oceania                      4                 4
# South America               11                11

# %% [markdown]
# # Relation between number of countries and sugarcane production.

# %%
num_countries=df['Country'].nunique()

# %%
total_production=df['Production_Tons'].sum()

# %%
average_production = df['Production_Tons'].mean()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Country'].head(10),df['Production_Tons'].head(10),color=['green','red','yellow'])
plt.title('Sugarcane Production by Country')
plt.xlabel('Country')
plt.ylabel('Sugarcane Production (tons)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.pie(df['Production_Tons'].head(5),labels=df['Country'].head(5),autopct='%2f.1%%')
plt.title('Sugarcane Production Distribution by Country')
plt.show()
